# %%
import os
from glob import glob
from pathlib import Path

import numpy as np
import xarray as xr
import pandas as pd

import pylab as plot
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set Paths
ROOT = Path("/gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/")
AUXDATA = Path(f"{ROOT}/aux_data")
RESULTS = Path(f"{ROOT}/calibration_results/pcr-globwb/")

# Set Config
basins_shp = f"{AUXDATA}/CAMELS-GB/data/CAMELS_GB_catchment_boundaries/CAMELS_GB_catchment_boundaries.shp"

results_wflow_csv = f"{ROOT}/results/wflow_sbm/evaluation_overview_wflow.csv"
results_pcrglob_csv = f"{ROOT}/results/pcr-globwb/evaluation_overview_pcrglobwb_adjusted_loc.csv"
results_selected_csv = f"{ROOT}"

# %%
df_wflow = pd.read_csv(results_wflow_csv, index_col='basin_id')
df_pcrglob = pd.read_csv(results_pcrglob_csv, index_col='basin_id')

df_selected = pd.read_csv(


df_eval = df_wflow.join(df_pcrglob, rsuffix='_pcrglob')
df_eval['diff'] = df_eval['kge_np'] - df_eval['kge_np_pcrglob']

# %%
df_eval
# Out:
#           Unnamed: 0    kge_np  kge_np_r  kge_np_alpha  kge_np_beta  kge_2009  \
# basin_id
# 34006              0  0.424443  0.926671      0.830600     1.543100 -0.201829
# 19020              1  0.801186  0.924529      0.916529     0.840386  0.627800
# 40003              2 -0.187371  0.501600      0.545514     0.060814 -0.564671
# 28033              3  0.699414  0.924214      0.927000     0.720843  0.663257
# 27003              4 -0.229286  0.444329      0.684271     0.008000 -0.595029
# ...              ...       ...       ...           ...          ...       ...
# 21011            645  0.615150  0.917600      0.937200     1.365200  0.568050
# 33026            646 -0.125214  0.716929      0.583643     0.001514 -0.475657
# 75004            647  0.741986  0.928729      0.931000     1.236729  0.741357
# 79006            648 -0.115186  0.562100      0.822200     0.000086 -0.525929
# 43017            649 -1.060071  0.794286      0.632871     3.013343 -5.356900
#
#           kge_2012        nse  Unnamed: 0_pcrglob  nse_pcrglob  \
# basin_id
# 34006     0.329614  -1.285857                   0       0.2123
# 19020     0.726571   0.744300                   0       0.0775
# 40003    -0.536014  -0.324543                   0       0.2650
# 28033     0.664114   0.751300                   0       0.3403
# 27003    -0.582157  -1.079329                   0       0.2124
# ...            ...        ...                 ...          ...
# 21011     0.548833   0.642000                   0      -0.0685
# 33026    -0.471643  -0.643486                   0       0.3273
# 75004     0.684257   0.814029                   0      -0.1135
# 79006    -0.238171  -0.664929                   0       0.1261
# 43017    -1.423629 -54.325414                   0      -5.7973
#
#           kge_2009_pcrglob  kge_2012_pcrglob  kge_np_pcrglob  \
# basin_id
# 34006               0.3385            0.3267          0.5901
# 19020               0.0464            0.0407          0.4847
# 40003               0.3422            0.2297          0.4791
# 28033               0.4172            0.3809          0.7104
# 27003               0.3019            0.2382          0.5937
# ...                    ...               ...             ...
# 21011               0.1174            0.0105          0.2635
# 33026               0.6021            0.5556          0.7059
# 75004               0.0573           -0.0740          0.0832
# 79006               0.1661            0.1151          0.4118
# 43017              -1.7652           -1.1646         -1.1576
#
#           kge_np_r_pcrglob  kge_np_alpha_pcrglob  kge_np_beta_pcrglob  \
# basin_id
# 34006               0.6662                0.7645               1.0332
# 19020               0.5959                0.6812               1.0240
# 40003               0.7775                0.7575               1.4037
# 28033               0.7733                0.8457               1.0932
# 27003               0.6961                0.8246               1.2049
# ...                    ...                   ...                  ...
# 21011               0.5070                0.7806               1.5013
# 33026               0.8502                0.8706               1.2176
# 75004               0.7964                0.8208               1.8758
# 79006               0.5079                0.7451               1.1971
# 43017               0.9234                0.9106               3.1544
#
#               diff
# basin_id
# 34006    -0.165657
# 19020     0.316486
# 40003    -0.666471
# 28033    -0.010986
# 27003    -0.822986
# ...            ...
# 21011     0.351650
# 33026    -0.831114
# 75004     0.658786
# 79006    -0.526986
# 43017     0.097529
#
# [650 rows x 17 columns]
