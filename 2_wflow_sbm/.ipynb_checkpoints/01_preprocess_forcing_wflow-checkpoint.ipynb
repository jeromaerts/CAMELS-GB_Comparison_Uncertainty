# %% [markdown]
# # Pre-process wflow_sbm forcing for CAMELS-GB in parallel
# ## CEH-GEAR: pr, CHESS-PE: pet, CHESS-met: tas

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
from glob import glob
from pathlib import Path

import os
import iris
import xarray as xr
import pandas as pd
from esmvalcore.preprocessor import regrid
from pathos.threading import ThreadPool as Pool
from dask.diagnostics import ProgressBar

# %%
# Snellius paths
ROOT = Path('/gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/')
AUXDATA = Path(f"{ROOT}/aux_data")
FORCING = Path(f'{ROOT}/forcing/')
MODELS = Path(f'{ROOT}/wflow/data/')

# %%
temp = ['15016',
 '16004',
 '17018',
 '18011',
 '19001',
 '21008',
 '21009',
 '23001',
 '25001',
 '26003',
 '26005',
 '27001',
 '27003',
 '27007',
 '27009',
 '27021',
 '27062',
 '27071',
 '27079',
 '27080',
 '27087',
 '28001',
 '28008',
 '28009',
 '28012',
 '28018',
 '28022',
 '28067',
 '28074',
 '28093',
 '28117',
 '33026',
 '33035',
 '33039',
 '38001',
 '39001',
 '39002',
 '39006',
 '39016',
 '39023',
 '39072',
 '40003',
 '4001',
 '42004',
 '43007',
 '47001',
 '50001',
 '54001',
 '54002',
 '54003',
 '54005',
 '54008',
 '54029',
 '54032',
 '54036',
 '54057',
 '54095',
 '55002',
 '55007',
 '55023',
 '56001',
 '60010',
 '6007',
 '62001',
 '67010',
 '67015',
 '67025',
 '67033',
 '69007',
 '71001',
 '72004',
 '75003',
 '76007',
 '77002',
 '78003',
 '79002',
 '79006',
 '80002',
 '8005',
 '8006',
 '84004',
 '84008',
 '84013',
 '84019',
 '89003',
 '89007',
 '9002']

# %% [markdown]
# # Config

# %%
#Time Period
start_year = "2000"
end_year = "2017"

# Get available basin IDs wflow_sbm
basin_dirs = glob(f'{MODELS}/*')
basin_ids = [s.split('/')[-1] for s in basin_dirs]
basin_ids.sort()

# Amount of available cores
cores_available = 30

# %% [markdown]
# # Preprocessor Function

# %%
# Prepare forcing function
def prep_forcing(basin_id, start_year, end_year):
    print(basin_id)
    # Create lists
    output = []
    output_da = []
    
    # Set basin directory
    BASINDIR = f'{MODELS}/{basin_id}/'
       
    # Open netCDF file as an example grid from the model directory
    cube_example = iris.load(f'{BASINDIR}/staticmaps.nc')[1]

    # Guess bounds   
    cube_example.coord('y').guess_bounds()
    cube_example.coord('x').guess_bounds()
    
    # Rename Coords
    cube_example.coord('y').rename('latitude')
    cube_example.coord('x').rename('longitude')
    
    cube_example.coord('latitude').units = 'degrees'
    cube_example.coord('longitude').units = 'degrees'
    
    # Loop forcing variables
    for variable in ['pr','tas','pet']:

        # Load forcing file
        cube_forcing = iris.load(glob(f'{FORCING}/*{variable}*')[0])[0]
        
        # Guess bounds
        cube_forcing.coord('latitude').guess_bounds()
        cube_forcing.coord('longitude').guess_bounds()

        # Regrid forcing file to example grid using conservative method
        cube_out = regrid(cube_forcing, cube_example, scheme='area_weighted')
        
        # Rename Coords
        cube_out.coord('latitude').rename('lat')
        cube_out.coord('longitude').rename('lon')
        
        # Convert to xarray and append to list
        da = xr.DataArray.from_iris(cube_out)
        output_da.append(da)
    
    # Change annoying long_name time
    for da in output_da:
        da.time.attrs = {'standard_name': 'time',
                         'long_name': 'time in days since 1961-01-01 00:00:00 UTC'}
        output.append(da)
    
    # Merge output variables
    ds = xr.merge(output)#, dim='time')
    ds = ds.rename({'lat': 'y', 'lon':'x', 'pr':'precip','tas': 'temp'})
    
    # Output filename
    output_fname = f'{BASINDIR}/ceh-gear_chess_camels-gb_{basin_id}_2000_2017.nc'
    
    # Remove existing file
    if output_fname:
        OUTPUT = Path(output_fname)
        OUTPUT.unlink(output_fname)
        
    # Save to netcdf
    write_job = ds.to_netcdf(output_fname, compute=False)
    with ProgressBar():
        write_job.compute()

    # ds.to_netcdf(output_fname)
    return print(f'{basin_id} finished: {output_fname}')

# %% [markdown]
# # Parallel Run function

# %%
def parallel_run(
    basin_ids,
    start_years,
    end_years, 
    threads=cores_available,
    ):
    
    # Set number of threads (cores) used for parallel run and map threads
    if threads is None:
        pool = Pool()
    else:
        pool = Pool(nodes=threads)
    # Run parallel models
    pool.map(
        prep_forcing,
        basin_ids,
        start_years,
        end_years,
        )
    return

# %% [markdown]
# ## Sort basins by size for lazy parallel

# %%
# Sort by basin size
def sort_basin_ids_by_size(basin_ids):
    sizes = []
    for basin_id in basin_ids:
        size = os.path.getsize(f'{MODELS}/{basin_id}/staticmaps.nc')
        sizes.append(size)

    df = pd.DataFrame()
    df['basin_id'] = basin_ids
    df['size'] = sizes
    df = df.sort_values('size')

    basin_ids = df.basin_id.to_list()
    
    return basin_ids

basin_ids_sorted = sort_basin_ids_by_size(basin_ids)

# %% [markdown]
# ## Create lists for lazy parallel

# %%
# Create lists for parallel runs
start_years = [start_year] * len(basin_ids_sorted)
end_years = [end_year] * len(basin_ids_sorted)

# %% [markdown]
# # Run parallel function

# %%
# Run function
parallel_run(basin_ids_sorted, start_years, end_years)
# Out:
# 4700118011
#
# 25001
# 21008
# 28093
# 28074
# 27087
# 39006
# 54008
# 55007
# 40003
# 4001
# 27007
# 67015
# 62001
# 27080
# 84004
# 27021
# 67025
# 56001
# 71001
# 28012
# 27071
# 54029
# 8005
# 33039
# 27002
# 85001
# 39008
# 21006
# [                                        ] | 0% Completed | 20.22 mss
# [                                        ] | 0% Completed | 77.23 sss
# [                                        ] | 0% Completed | 148.95 ss
# [#                                       ] | 4% Completed | 194.97 ss
# [                                        ] | 0% Completed | 180.91 ss
# [                                        ] | 0% Completed | 24.51 s s
# [########################################] | 100% Completed | 13.19 s
# [#######                                 ] | 17% Completed | 260.39 s
# [                                        ] | 0% Completed | 17.20 s s

# %%
parallel_run(basin_ids_sorted, start_years, end_years)

# %% [markdown]
# # Check completed runs

# %%
df = pd.DataFrame()
basins = []
exists = []

for basin_id in basin_ids_sorted:
    basins.append(basin_id)
   
    # check if file exists
    file = Path(f'{MODELS}/{basin_id}/ceh-gear_chess_camels-gb_{basin_id}_2000_2017.nc')
    exists.append(file.is_file())
    
df['basin_id'] = basins
df['completed'] = exists
df = df[df['completed'] == False]    
df
# Out:
# Empty DataFrame
# Columns: [basin_id, completed]
# Index: []

# %%
for basin_id in temp:
    prep_forcing(basin_id, start_year, end_year)
# Out:
# 15016
# [########################################] | 100% Completed | 80.97 s
# 15016 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/15016//ceh-gear_chess_camels-gb_15016_2000_2017.nc
# 16004
# [########################################] | 100% Completed | 73.67 s
# 16004 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/16004//ceh-gear_chess_camels-gb_16004_2000_2017.nc
# 17018
# [########################################] | 100% Completed | 34.53 s
# 17018 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/17018//ceh-gear_chess_camels-gb_17018_2000_2017.nc
# 18011
# [########################################] | 100% Completed | 79.97 s
# 18011 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/18011//ceh-gear_chess_camels-gb_18011_2000_2017.nc
# 19001
# [########################################] | 100% Completed | 55.71 s
# 19001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/19001//ceh-gear_chess_camels-gb_19001_2000_2017.nc
# 21008
# [########################################] | 100% Completed | 87.26 s
# 21008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/21008//ceh-gear_chess_camels-gb_21008_2000_2017.nc
# 21009
# [########################################] | 100% Completed | 273.82 s
# 21009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/21009//ceh-gear_chess_camels-gb_21009_2000_2017.nc
# 23001
# [########################################] | 100% Completed | 140.19 s
# 23001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/23001//ceh-gear_chess_camels-gb_23001_2000_2017.nc
# 25001
# [########################################] | 100% Completed | 83.61 s
# 25001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/25001//ceh-gear_chess_camels-gb_25001_2000_2017.nc
# 26003
# [########################################] | 100% Completed | 31.82 s
# 26003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/26003//ceh-gear_chess_camels-gb_26003_2000_2017.nc
# 26005
# [########################################] | 100% Completed | 43.18 s
# 26005 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/26005//ceh-gear_chess_camels-gb_26005_2000_2017.nc
# 27001
# [########################################] | 100% Completed | 69.62 s
# 27001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/27001//ceh-gear_chess_camels-gb_27001_2000_2017.nc
# 27003
# [########################################] | 100% Completed | 179.69 s
# 27003 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/27003//ceh-gear_chess_camels-gb_27003_2000_2017.nc
# 27007
# [########################################] | 100% Completed | 106.73 s
# 27007 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/27007//ceh-gear_chess_camels-gb_27007_2000_2017.nc
# 27009
# [########################################] | 100% Completed | 233.21 s
# 27009 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/27009//ceh-gear_chess_camels-gb_27009_2000_2017.nc
# 27021
# [########################################] | 100% Completed | 128.57 s
# 27021 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/27021//ceh-gear_chess_camels-gb_27021_2000_2017.nc
# 27062
# [########################################] | 100% Completed | 88.00 s
# 27062 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/27062//ceh-gear_chess_camels-gb_27062_2000_2017.nc
# 27071
# [########################################] | 100% Completed | 113.98 s
# 27071 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/27071//ceh-gear_chess_camels-gb_27071_2000_2017.nc
# 27079
# [########################################] | 100% Completed | 92.94 s
# 27079 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/27079//ceh-gear_chess_camels-gb_27079_2000_2017.nc
# 27080
# [########################################] | 100% Completed | 119.52 s
# 27080 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/27080//ceh-gear_chess_camels-gb_27080_2000_2017.nc
# 27087
# [########################################] | 100% Completed | 104.02 s
# 27087 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/27087//ceh-gear_chess_camels-gb_27087_2000_2017.nc
# 28001
# [########################################] | 100% Completed | 42.84 s
# 28001 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/28001//ceh-gear_chess_camels-gb_28001_2000_2017.nc
# 28008
# [########################################] | 100% Completed | 54.00 s
# 28008 finished: /gpfs/work1/0/wtrcycle/users/jaerts/camels_uk/wflow/data/28008//ceh-gear_chess_camels-gb_28008_2000_2017.nc
# 28009
# [                                        ] | 0% Completed | 47.05 sms
